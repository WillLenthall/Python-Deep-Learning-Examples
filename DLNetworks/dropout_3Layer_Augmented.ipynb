# %%
from keras.preprocessing.image import ImageDataGenerator

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"  #Kernal kept crashing

train_directory = 'Data/signlang/train'
test_directory = 'Data/signlang/test'
validation_directory = 'Data/signlang/val'

# %%
train_datagen = ImageDataGenerator(rotation_range = 5, rescale=1./255, width_shift_range = 0.025, height_shift_range = 0.025, shear_range = 0.025, horizontal_flip = True, fill_mode = 'nearest')
test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_directory, target_size=(100,100), batch_size=20, class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(validation_directory, target_size=(100,100),batch_size=20, class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_directory, target_size=(100,100),batch_size=20, class_mode='categorical', shuffle = False)
# Out:
# Found 1929 images belonging to 10 classes.
# Found 548 images belonging to 10 classes.
# Found 287 images belonging to 10 classes.

# %%
from keras import models, layers

network = models.Sequential()
network.add(layers.Conv2D(32, (3,3), activation='relu',input_shape=(100,100,3)))
network.add(layers.MaxPooling2D(2,2))
network.add(layers.Conv2D(128, (3,3), activation='relu',input_shape=(100,100,3)))
network.add(layers.MaxPooling2D(2,2))
network.add(layers.Conv2D(128, (3,3), activation='relu',input_shape=(100,100,3)))
network.add(layers.MaxPooling2D(2,2))
network.add(layers.Flatten())
network.add(layers.Dropout(0.5))
network.add(layers.Dense(512))
network.add(layers.Dense(10, activation='softmax'))
            
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 128)       36992
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dropout (Dropout)           (None, 12800)             0
#
#  dense (Dense)               (None, 512)               6554112
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,744,714
# Trainable params: 6,744,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
network.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
history = network.fit(train_generator, steps_per_epoch = 50, epochs = 35, validation_data = validation_generator, validation_steps = 25)
# Out:
# Epoch 1/35
# 50/50 [==============================] - 13s 226ms/step - loss: 2.9256 - accuracy: 0.1890 - val_loss: 1.8909 - val_accuracy: 0.3000
# Epoch 2/35
# 50/50 [==============================] - 11s 218ms/step - loss: 1.6310 - accuracy: 0.4120 - val_loss: 1.3864 - val_accuracy: 0.4740
# Epoch 3/35
# 50/50 [==============================] - 11s 218ms/step - loss: 1.2448 - accuracy: 0.5379 - val_loss: 0.9232 - val_accuracy: 0.6960
# Epoch 4/35
# 50/50 [==============================] - 11s 212ms/step - loss: 0.9421 - accuracy: 0.6673 - val_loss: 0.8822 - val_accuracy: 0.6560
# Epoch 5/35
# 50/50 [==============================] - 12s 245ms/step - loss: 0.7902 - accuracy: 0.7230 - val_loss: 0.6157 - val_accuracy: 0.8060
# Epoch 6/35
# 50/50 [==============================] - 12s 239ms/step - loss: 0.6718 - accuracy: 0.7640 - val_loss: 0.6647 - val_accuracy: 0.7880
# Epoch 7/35
# 50/50 [==============================] - 12s 237ms/step - loss: 0.6039 - accuracy: 0.7900 - val_loss: 0.4925 - val_accuracy: 0.8400
# Epoch 8/35
# 50/50 [==============================] - 13s 255ms/step - loss: 0.5141 - accuracy: 0.8300 - val_loss: 0.5618 - val_accuracy: 0.8360
# Epoch 9/35
# 50/50 [==============================] - 13s 252ms/step - loss: 0.4887 - accuracy: 0.8380 - val_loss: 0.4215 - val_accuracy: 0.8600
# Epoch 10/35
# 50/50 [==============================] - 25s 512ms/step - loss: 0.4826 - accuracy: 0.8665 - val_loss: 0.3946 - val_accuracy: 0.8880
# Epoch 11/35
# 50/50 [==============================] - 17s 334ms/step - loss: 0.4599 - accuracy: 0.8530 - val_loss: 0.4886 - val_accuracy: 0.8640
# Epoch 12/35
# 50/50 [==============================] - 14s 275ms/step - loss: 0.4024 - accuracy: 0.8756 - val_loss: 0.4295 - val_accuracy: 0.8620
# Epoch 13/35
# 50/50 [==============================] - 13s 249ms/step - loss: 0.4226 - accuracy: 0.8760 - val_loss: 0.4497 - val_accuracy: 0.8600
# Epoch 14/35
# 50/50 [==============================] - 12s 239ms/step - loss: 0.3631 - accuracy: 0.8840 - val_loss: 0.4523 - val_accuracy: 0.8720
# Epoch 15/35
# 50/50 [==============================] - 12s 234ms/step - loss: 0.3562 - accuracy: 0.8888 - val_loss: 0.4360 - val_accuracy: 0.8900
# Epoch 16/35
# 50/50 [==============================] - 12s 233ms/step - loss: 0.3382 - accuracy: 0.9020 - val_loss: 0.4789 - val_accuracy: 0.8720
# Epoch 17/35
# 50/50 [==============================] - 12s 229ms/step - loss: 0.3743 - accuracy: 0.8706 - val_loss: 0.4302 - val_accuracy: 0.8660
# Epoch 18/35
# 50/50 [==============================] - 11s 226ms/step - loss: 0.3382 - accuracy: 0.8878 - val_loss: 0.4394 - val_accuracy: 0.8840
# Epoch 19/35
# 50/50 [==============================] - 12s 239ms/step - loss: 0.3617 - accuracy: 0.8938 - val_loss: 0.3007 - val_accuracy: 0.9100
# Epoch 20/35
# 50/50 [==============================] - 12s 236ms/step - loss: 0.3234 - accuracy: 0.8898 - val_loss: 0.3385 - val_accuracy: 0.9100
# Epoch 21/35
# 50/50 [==============================] - 12s 238ms/step - loss: 0.3460 - accuracy: 0.8918 - val_loss: 0.4428 - val_accuracy: 0.8700
# Epoch 22/35
# 50/50 [==============================] - 12s 232ms/step - loss: 0.3433 - accuracy: 0.8918 - val_loss: 0.2599 - val_accuracy: 0.9180
# Epoch 23/35
# 50/50 [==============================] - 12s 245ms/step - loss: 0.2803 - accuracy: 0.9050 - val_loss: 0.3271 - val_accuracy: 0.8900
# Epoch 24/35
# 50/50 [==============================] - 12s 245ms/step - loss: 0.2288 - accuracy: 0.9191 - val_loss: 0.3096 - val_accuracy: 0.9140
# Epoch 25/35
# 50/50 [==============================] - 12s 234ms/step - loss: 0.2989 - accuracy: 0.9120 - val_loss: 0.3371 - val_accuracy: 0.9080
# Epoch 26/35
# 50/50 [==============================] - 12s 234ms/step - loss: 0.3306 - accuracy: 0.9009 - val_loss: 0.3852 - val_accuracy: 0.9000
# Epoch 27/35
# 50/50 [==============================] - 12s 234ms/step - loss: 0.3225 - accuracy: 0.9009 - val_loss: 0.2635 - val_accuracy: 0.9280
# Epoch 28/35
# 50/50 [==============================] - 12s 234ms/step - loss: 0.2487 - accuracy: 0.9210 - val_loss: 0.3521 - val_accuracy: 0.8920
# Epoch 29/35
# 50/50 [==============================] - 12s 242ms/step - loss: 0.2771 - accuracy: 0.9210 - val_loss: 0.2581 - val_accuracy: 0.9280
# Epoch 30/35
# 50/50 [==============================] - 12s 232ms/step - loss: 0.2652 - accuracy: 0.9151 - val_loss: 0.3057 - val_accuracy: 0.9080
# Epoch 31/35
# 50/50 [==============================] - 13s 251ms/step - loss: 0.2520 - accuracy: 0.9161 - val_loss: 0.3823 - val_accuracy: 0.8920
# Epoch 32/35
# 50/50 [==============================] - 12s 232ms/step - loss: 0.2421 - accuracy: 0.9310 - val_loss: 0.2651 - val_accuracy: 0.9200
# Epoch 33/35
# 50/50 [==============================] - 12s 241ms/step - loss: 0.2537 - accuracy: 0.9310 - val_loss: 0.3451 - val_accuracy: 0.9000
# Epoch 34/35
# 50/50 [==============================] - 12s 237ms/step - loss: 0.2683 - accuracy: 0.9230 - val_loss: 0.3386 - val_accuracy: 0.9080
# Epoch 35/35
# 50/50 [==============================] - 12s 232ms/step - loss: 0.2187 - accuracy: 0.9280 - val_loss: 0.3648 - val_accuracy: 0.9040

# %%
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1,len(acc)+1)
plt.plot(epochs, acc, 'bo', label = 'Training_accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Val_accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(epochs, loss, 'bo', label = 'Training_loss')
plt.plot(epochs, val_loss, 'b', label = 'Val_loss')
plt.title('Training and validation Loss')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
res = network.evaluate(test_generator, steps = 14, verbose = 1)
print('Accuracy on test set: %.3f'%res[1])
# Out:
# 14/14 [==============================] - 2s 183ms/step - loss: 0.3029 - accuracy: 0.9143
# Accuracy on test set: 0.914
